# %% [markdown]
# # **PRAKTIKUM 1**

# %% [markdown]
# Langkah 1: Import Library dan Mount Google Drive

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import cv2

from skimage.feature import hog
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Langkah 2: Load Dataset

# %%
# Load images and labels from a directory structure
def load_dataset(img_dir):
    p = Path(img_dir)
    img_list = []
    for folder in p.glob('*'):
        label = folder.name
        for file in folder.glob('*.jpg'):
            img = cv2.imread(str(file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_list.append((img, label))
    return img_list

train_dir = "/content/drive/MyDrive/Colab Notebooks/Machine_Learning_25/dataset/JS15/images/training/"
test_dir  = "/content/drive/MyDrive/Colab Notebooks/Machine_Learning_25/dataset/JS15/images/test"

train_img = load_dataset(train_dir)
test_img  = load_dataset(test_dir)

print(f"Jumlah data training: {len(train_img)}")
print(f"Jumlah data testing: {len(test_img)}")
# Out:
# Jumlah data training: 240
# Jumlah data testing: 160

# %% [markdown]
# Langkah 3: Preprocessing (Resize & Label Encoding)

# %%
# Preprocess images: resize and encode labels
def resize_image(img, size=(256,256)):
    return cv2.resize(img, size)

def label_encoder(label):
    return 1 if label == 'day' else 0

def preprocess(img_list):
    X = []
    y = []
    for img, label in img_list:
        img_std = resize_image(img)
        X.append(img_std)
        y.append(label_encoder(label))
    return X, y

X_train_img, y_train = preprocess(train_img)
X_test_img,  y_test  = preprocess(test_img)

# %% [markdown]
# Langkah 4: Ekstraksi Fitur HOG (Histogram of Oriented Gradients)

# %%
# Extract HOG features
def extract_hog(X_imgs):
    feats = []
    for img in X_imgs:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        hog_feat = hog(gray,
                       orientations=9,
                       pixels_per_cell=(8,8),
                       cells_per_block=(2,2),
                       block_norm='L2-Hys',
                       visualize=False,
                       feature_vector=True)
        feats.append(hog_feat)
    return np.array(feats)

X_train_feat = extract_hog(X_train_img)
X_test_feat  = extract_hog(X_test_img)

# %% [markdown]
# Langkah 5: Normalisasi Fitur

# %%
# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_feat)
X_test_scaled  = scaler.transform(X_test_feat)

# %% [markdown]
# Langkah 6: Split Data Training & Validation

# %%
# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_scaled, y_train,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# Langkah 7: Konversi Label ke Numpy Array

# %%
# Convert labels to numpy arrays (required for Keras)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %% [markdown]
# Langkah 8: Membangun Arsitektur Model Neural Network

# %%
# Build a simple feedforward neural network
# Define model architecture
# input_dim is the number of features in the dataset
# Hidden layer -> 128 neurons, ReLU activation
# Hidden layer -> 64 neurons, ReLU activation
# Output layer -> 1 neuron, Sigmoid activation (for binary classification)
input_dim = X_train.shape[1]

model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     4,428,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,436,737 (16.92 MB)
#  Trainable params: 4,436,737 (16.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Langkah 9: Training Model

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.7116 - loss: 1.1334 - val_accuracy: 0.8958 - val_loss: 0.3547
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9985 - loss: 0.0295 - val_accuracy: 0.8958 - val_loss: 0.3160
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8958 - val_loss: 0.4740
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 4.2479e-05 - val_accuracy: 0.9792 - val_loss: 0.2595
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 5.1578e-05 - val_accuracy: 0.9375 - val_loss: 0.2904
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 9.1365e-05 - val_accuracy: 0.9375 - val_loss: 0.3066
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.5571e-05 - val_accuracy: 0.9375 - val_loss: 0.3076
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 1.0000 - loss: 2.7783e-06 - val_accuracy: 0.9375 - val_loss: 0.3080
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 3.0405e-06 - val_accuracy: 0.9375 - val_loss: 0.3081
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 1.9139e-06 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 1.4662e-06 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 1.5515e-06 - val_accuracy: 0.9375 - val_loss: 0.3083
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 1.0000 - loss: 1.1280e-06 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 1.0000 - loss: 1.2757e-06 - val_accuracy: 0.9375 - val_loss: 0.3083
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 1.0000 - loss: 9.5802e-07 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 1.0000 - loss: 1.2952e-06 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 1.0000 - loss: 8.7986e-07 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 1.7971e-06 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.6657e-06 - val_accuracy: 0.9375 - val_loss: 0.3082
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 1.7492e-06 - val_accuracy: 0.9375 - val_loss: 0.3082

# %% [markdown]
# Langkah 10: Evaluasi Model

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(X_test_scaled, y_test)
print("Akurasi Test:", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9561 - loss: 0.5230
# Akurasi Test: 0.9437500238418579

# %% [markdown]
# Langkah 11: Prediksi dan Laporan Klasifikasi serta Visualisasi

# %%
# Generate classification report and confusion matrix
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95        80
#            1       0.97      0.91      0.94        80
#
#     accuracy                           0.94       160
#    macro avg       0.95      0.94      0.94       160
# weighted avg       0.95      0.94      0.94       160
#
# [[78  2]
#  [ 7 73]]

# %%
# Visualize training history
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Langkah 12: Menyimpan Model dan Scaler

# %%
# Save the trained model
import pickle

# 1. Simpan Model
# Menggunakan format .h5
model.save('day_night_model.h5')
print("✅ Model berhasil disimpan sebagai: day_night_model.h5")

# 2. Simpan Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✅ Scaler berhasil disimpan sebagai: scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model berhasil disimpan sebagai: day_night_model.h5
# ✅ Scaler berhasil disimpan sebagai: scaler.pkl
